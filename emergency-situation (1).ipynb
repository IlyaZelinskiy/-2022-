# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")

# %%
df1 = pd.read_csv('../input/dataset/01-06.2020 (1).csv', encoding='cp1252', on_bad_lines='skip')
df2 = pd.read_csv('../input/dataset/01-06.2021 (1).csv', encoding='cp1252', on_bad_lines='skip')
df3 = pd.read_csv('../input/dataset/01-09.2019 (1).csv', encoding='cp1252', on_bad_lines='skip')
df4 = pd.read_csv('../input/dataset/07-12.2020 (1).csv', encoding='cp1252', on_bad_lines='skip')
df5 = pd.read_csv('../input/dataset/07-12.2021 (1).csv', encoding='cp1252', on_bad_lines='skip')
df6 = pd.read_csv('../input/dataset/10-12.2019 (1).csv', encoding='cp1252', on_bad_lines='skip')

# %%
index1 = df1.columns.tolist() #39 ok
index2 = df2.columns.tolist() #37 ok
index3 = df3.columns.tolist() #37 bad
index4 = df4.columns.tolist() #36 ok
index5 = df5.columns.tolist() #35 ok
index6 = df6.columns.tolist() #36 bad

# %%
listOfcolumns = ['cdPn', 'cgPn', 'hrId', 'name', 'type', 'ierId', 'level', 'point', 'state', 'action', 'cardId', 'isNear', 'region', 'ierType', 'cityCode', 'isDanger.', 'isDanger', 'regionId', 'cityFiasId', 'isBlocking', 'isMalicius', 'lostNumber', 'membership', 'streetCode', 'timeIsoStr', 'isChemFlood','dispatchesId ', 'districtCode', 'streetFiasId','clarification', 'injuredNumber', 'responseStatus', 'actionTimeIsoStr', 'assignTimeIsoStr', 'acceptOperatorFio', 'acceptOperatorStr','','','']
array1 = []
for i in range(1,len(df1)):
    a = df1[index1[0]][i].strip().split(';')#очищаем от говна в массив говна 
    a.pop(39)
    array1.append(a)

df01_06_2020 = pd.DataFrame(array1, columns=listOfcolumns)

# %%
listOfcolumns = ['cdPn', 'cgPn', 'hrId', 'name', 'type', 'ierId', 'level', 'point', 'state', 'action', 'cardId', 'isNear', 'region', 'ierType', 'cityCode', 'isDanger.', 'isDanger', 'regionId', 'cityFiasId', 'isBlocking', 'isMalicius', 'lostNumber', 'membership', 'streetCode', 'timeIsoStr', 'isChemFlood','dispatchesId ', 'districtCode', 'streetFiasId','clarification', 'injuredNumber', 'responseStatus', 'actionTimeIsoStr', 'assignTimeIsoStr', 'acceptOperatorFio', 'acceptOperatorStr','']

array2 = []
for i in range(1,len(df2)):
    a = df2[index2[0]][i].strip().split(';')#очищаем от говна в массив говна 
    a.pop(37)
    array2.append(a)

df01_06_2021 = pd.DataFrame(array2, columns=listOfcolumns)

# %%
listOfcolumns = ['cdPn', 'cgPn', 'hrId', 'name', 'type', 'ierId', 'level', 'point', 'state', 'action', 'cardId', 'isNear', 'region', 'ierType', 'cityCode', 'isDanger.', 'isDanger', 'regionId', 'cityFiasId', 'isBlocking', 'isMalicius', 'lostNumber', 'membership', 'streetCode', 'timeIsoStr', 'isChemFlood','dispatchesId ', 'districtCode', 'streetFiasId','clarification', 'injuredNumber', 'responseStatus', 'actionTimeIsoStr', 'assignTimeIsoStr', 'acceptOperatorFio', 'acceptOperatorStr','']

array4 = []
for i in range(1,len(df4)):
    a = df4[index4[0]][i].strip().split(';')#очищаем от говна в массив говна 
    #a.pop(37)
    array4.append(a)

df07_12_2020 = pd.DataFrame(array4, columns=listOfcolumns)

# %%
listOfcolumns = ['cdPn', 'cgPn', 'hrId', 'name', 'type', 'ierId', 'level', 'point', 'state', 'action', 'cardId', 'isNear', 'region', 'ierType', 'cityCode', 'isDanger.', 'isDanger', 'regionId', 'cityFiasId', 'isBlocking', 'isMalicius', 'lostNumber', 'membership', 'streetCode', 'timeIsoStr', 'isChemFlood','dispatchesId ', 'districtCode', 'streetFiasId','clarification', 'injuredNumber', 'responseStatus', 'actionTimeIsoStr', 'assignTimeIsoStr', 'acceptOperatorStr','']

array5 = []
for i in range(1,len(df5)):
    a = df5[index5[0]][i].strip().split(';')#очищаем от говна в массив говна 
    #a.pop(35)
    array5.append(a)

df07_12_2021 = pd.DataFrame(array5, columns=listOfcolumns)

# %%
df01_06_2020.head(3)

# %% [markdown]
# Расшифруем названия колонок сделаем декодинг и уберем пустые колонки

# %%
#df01_06_2020
for i in range(len(df01_06_2020)):
    a = df01_06_2020['name'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2020.loc[i, "name"] = b.rstrip()
    a= df01_06_2020['hrId'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2020.loc[i, "hrId"] = b.rstrip()
    a= df01_06_2020['type'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2020.loc[i, "type"] = b.rstrip()
    a= df01_06_2020['level'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2020.loc[i, "level"] = b.rstrip()
    a= df01_06_2020['state'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2020.loc[i, "state"] = b.rstrip()# присваиваем [1] по инексу [0] в столбце [delay]
    a= df01_06_2020['region'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2020.loc[i, "region"] = b.rstrip()
    a= df01_06_2020['membership'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2020.loc[i, "membership"] = b.rstrip()
    a= df01_06_2020['membership'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2020.loc[i, "membership"] = b.rstrip()
df01_06_2020 = df01_06_2020.drop(['cdPn', 'cgPn', 'name', 'ierId', 'point', 'action','isDanger.', 'isNear','ierType', 'cityCode', 'cityFiasId', 'isMalicius', 'membership', 'streetCode', 'clarification', 'injuredNumber', 'actionTimeIsoStr', 'acceptOperatorFio', 'acceptOperatorStr', 'districtCode', 'streetFiasId', 'dispatchesId ','hrId', 'regionId', 'isBlocking',''], axis = 1)

# %%
#df07_12_2020
for i in range(len(df07_12_2020)):#0
    a = df07_12_2020['name'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "name"] = b.rstrip()
    a= df07_12_2020['hrId'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "hrId"] = b.rstrip()
    a= df07_12_2020['type'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "type"] = b.rstrip()
    a= df07_12_2020['level'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "level"] = b.rstrip()
    a= df07_12_2020['state'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "state"] = b.rstrip()# присваиваем [1] по инексу [0] в столбце [delay]
    a= df07_12_2020['region'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "region"] = b.rstrip()
    a= df07_12_2020['membership'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "membership"] = b.rstrip()
    a= df07_12_2020['membership'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "membership"] = b.rstrip()
    a= df07_12_2020['cgPn'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "cgPn"] = b.rstrip()
    a= df07_12_2020['ierId'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, "ierId"] = b.rstrip()
    a= df07_12_2020['isNear'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, 'isNear'] = b.rstrip()
    a= df07_12_2020['lostNumber'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, 'lostNumber'] = b.rstrip()
    a= df07_12_2020['lostNumber'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, 'lostNumber'] = b.rstrip()
    a= df07_12_2020['point'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2020.loc[i, 'point'] = b.rstrip()

df07_12_2020 = df07_12_2020.drop(['cdPn', 'cgPn', 'hrId', 'level', 'type','state', 'isDanger','region', 'acceptOperatorFio', 'acceptOperatorStr','ierType','cityCode', 'regionId','isBlocking', 'lostNumber','membership', 'cityFiasId', 'isChemFlood','responseStatus', 'assignTimeIsoStr','districtCode', 'streetFiasId','clarification','dispatchesId '], axis = 1)#3
df07_12_2020.rename(columns = {'timeIsoStr':'isChemFlood'}, inplace = True)#1
df07_12_2020.rename(columns = {'name' : 'type', 'cardId': 'card', 'action' : 'cardId', 'ierId': 'level', 'point':'state','isNear': 'region', 'isDanger.': 'isDanger','isMalicius': 'lostNumber','streetCode': 'timeIsoStr','injuredNumber':'responseStatus','actionTimeIsoStr':'assignTimeIsoStr'}, inplace = True)#2

df07_12_2020 = df07_12_2020.drop(['card'], axis = 1)#4
df07_12_2020 = df07_12_2020.drop([''],axis = 1)

# %%
#df01_06_2021
for i in range(len(df01_06_2021)):#0
    a = df01_06_2021['name'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "name"] = b.rstrip()
    a= df01_06_2021['hrId'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "hrId"] = b.rstrip()
    a= df01_06_2021['type'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "type"] = b.rstrip()
    a= df01_06_2021['level'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "level"] = b.rstrip()
    a= df01_06_2021['state'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "state"] = b.rstrip()# присваиваем [1] по инексу [0] в столбце [delay]
    a= df01_06_2021['region'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "region"] = b.rstrip()
    a= df01_06_2021['membership'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "membership"] = b.rstrip()
    a= df01_06_2021['membership'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "membership"] = b.rstrip()
    a= df01_06_2021['cgPn'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "cgPn"] = b.rstrip()
    a= df01_06_2021['ierId'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, "ierId"] = b.rstrip()
    a= df01_06_2021['isNear'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, 'isNear'] = b.rstrip()
    a= df01_06_2021['lostNumber'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, 'lostNumber'] = b.rstrip()
    a= df01_06_2021['lostNumber'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, 'lostNumber'] = b.rstrip()
    a= df01_06_2021['point'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df01_06_2021.loc[i, 'point'] = b.rstrip()

df01_06_2021 = df01_06_2021.drop(['cdPn', 'cgPn', 'hrId', 'level', 'type','state', 'isDanger','region', 'acceptOperatorFio', 'acceptOperatorStr','ierType','cityCode', 'regionId','isBlocking', 'lostNumber','membership', 'cityFiasId', 'isChemFlood','responseStatus', 'assignTimeIsoStr','districtCode', 'streetFiasId','clarification','dispatchesId '], axis = 1)#3
df01_06_2021.rename(columns = {'timeIsoStr':'isChemFlood'}, inplace = True)#1
df01_06_2021.rename(columns = {'name' : 'type', 'cardId': 'card', 'action' : 'cardId', 'ierId': 'level', 'point':'state','isNear': 'region', 'isDanger.': 'isDanger','isMalicius': 'lostNumber','streetCode': 'timeIsoStr','injuredNumber':'responseStatus','actionTimeIsoStr':'assignTimeIsoStr'}, inplace = True)#2

df01_06_2021 = df01_06_2021.drop(['card'], axis = 1)#4
df01_06_2021 = df01_06_2021.drop([''],axis = 1)

# %%
#df07_12_2021
for i in range(len(df07_12_2021)):#0
    a = df07_12_2021['name'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "name"] = b.rstrip()
    a= df07_12_2021['hrId'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "hrId"] = b.rstrip()
    a= df07_12_2021['type'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "type"] = b.rstrip()
    a= df07_12_2021['level'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "level"] = b.rstrip()
    a= df07_12_2021['state'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "state"] = b.rstrip()# присваиваем [1] по инексу [0] в столбце [delay]
    a= df07_12_2021['region'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "region"] = b.rstrip()
    a= df07_12_2021['membership'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "membership"] = b.rstrip()
    a= df07_12_2021['membership'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "membership"] = b.rstrip()
    a= df07_12_2021['cgPn'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "cgPn"] = b.rstrip()
    a= df07_12_2021['ierId'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, "ierId"] = b.rstrip()
    a= df07_12_2021['isNear'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, 'isNear'] = b.rstrip()
    a= df07_12_2021['lostNumber'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, 'lostNumber'] = b.rstrip()
    a= df07_12_2021['lostNumber'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, 'lostNumber'] = b.rstrip()
    a= df07_12_2021['point'][i]
    b = a.encode(encoding='ISO-8859-1', errors='ignore').decode('cp1251')
    df07_12_2021.loc[i, 'point'] = b.rstrip()

df07_12_2021 = df07_12_2021.drop(['cdPn', 'cgPn', 'hrId','type','state','level','region','ierType','regionId','isDanger','cityCode','isBlocking','cityFiasId','lostNumber','membership','dispatchesId ', 'districtCode', 'streetFiasId','acceptOperatorStr','assignTimeIsoStr','clarification','cardId',''], axis = 1)
df07_12_2021.rename(columns = {'name' : 'type','point':'state','ierId':'level','isNear':'region','isDanger.':'isDanger','isMalicius':'lostNumber','actionTimeIsoStr':'assignTimeIsoStr','action':'cardId'}, inplace = True)
df07_12_2021 = df07_12_2021.drop(['isChemFlood','responseStatus'], axis = 1)
df07_12_2021.rename(columns = {'timeIsoStr':'isChemFlood','injuredNumber':'responseStatus','streetCode':'timeIsoStr'}, inplace = True)

# %%
df07_12_2020.head(1)

# %%
df07_12_2021

# %% [markdown]
# Объединим таблицы за два года

# %%
dataFrameBig = pd.concat([df01_06_2020, df07_12_2020, df01_06_2021, df07_12_2021])

# %%
dataFrameBig

# %% [markdown]
# Сохраним dataFrame в csv файл

# %%
dataFrameBig.to_csv('dataFrame2020_2021.csv', index = False)

# %%
dataFrameBig.info()

# %% [markdown]
# # **Анализ имеющегося массива данных по свершившимся происшествиям на территории Волгоградской области, в том числе в разрезе муниципальных образований;**

# %%
dataFrameBig['type'].value_counts()#типы всевозможных происшествий

# %%
# Set the width and height of the figure
plt.figure(figsize=(15,10))

# Add title
plt.title("вызовы в службы на территории Волгоградской области за 2020 и 2021 год")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(y=dataFrameBig['type'].value_counts().keys(), x=dataFrameBig['type'].value_counts())

# Add label for vertical axis
plt.xlabel("число вызовов")

# %% [markdown]
# **Мы можем заметить, что случайный набор номера занимает большое число вызовов, это может негативно сказываться на загруженности call-центров, которым поступают вызовы от граждан, одним из способов решения данной проблымы может быть подключение робота, каоторый будет принимать первичную информацию от граждан**
#
# **Следующей колонкой идет значение "не заданно" и эту информацию можно рассматривать по разному, поэтому опустим её**
#
# **"Прерывание вызова звонящим сразу после подключени" и "Вызов с молчанием" можно также решить с помощью создание робота**
#
# **Уберем эти колонки и посмотрим на оставшиеся происшествия в разрезе по областям**

# %%
dataFrameBig = dataFrameBig.loc[~dataFrameBig['type'].isin(['Случайный набор номера', 'не задано', 'Прерывание вызова звонящим сразу после подключения', 'Вызов с молчанием'])]
#df01_06_2020.drop(['Случайный набор номера', 'не задано', 'Прерывание вызова звонящим сразу после подключения', 'Вызов с молчанием'], axis = 0)

# %%
dataFrameBig['region'].value_counts().keys().tolist()[7:]

# %%
a1= dataFrameBig.loc[dataFrameBig['region'] == 'Палласовский']
a2= dataFrameBig.loc[dataFrameBig['region'] == 'Котовский']
a3= dataFrameBig.loc[dataFrameBig['region'] == 'Волгоград Красноармейский']
a4= dataFrameBig.loc[dataFrameBig['region'] == 'Суровикинский']
a5= dataFrameBig.loc[dataFrameBig['region'] == 'Камышинский']
a6= dataFrameBig.loc[dataFrameBig['region'] == 'Фроловский']
a7= dataFrameBig.loc[dataFrameBig['region'] == 'Новоаннинский']
a8= dataFrameBig.loc[dataFrameBig['region'] == 'Алексеевский']
a9= dataFrameBig.loc[dataFrameBig['region'] == 'Волгоград Краснооктябрьский']
a10= dataFrameBig.loc[dataFrameBig['region'] == 'Новониколаевский']
a11= dataFrameBig.loc[dataFrameBig['region'] == 'Среднеахтубинский']
a12= dataFrameBig.loc[dataFrameBig['region'] == 'Ольховский']
a13= dataFrameBig.loc[dataFrameBig['region'] == 'Чернышковский']
a14= dataFrameBig.loc[dataFrameBig['region'] == 'Михайловский']
df = pd.concat([a1,a2,a3,a4,a5,a6,a7,a8,a9,a10,a11,a12,a13,a14])

# %%
dataFrameBig.loc[dataFrameBig['region']=='Волгоград Ворошиловский']['type'].value_counts()

# %%
    plt.figure(figsize=(10,8))
    plt.title("вызовы в службы на территории остальных* районов за 2020 и 2021 год")
    sns.barplot(y=df['type'].value_counts().keys(), x=df['type'].value_counts())
    plt.xlabel("число вызовов")

# %% [markdown]
# Большую часть вызовов является получение справок, чтобы уменьшить нагрузку на call центры, можно также перевести эту задачу на роботов.

# %%
for i in dataFrameBig['region'].value_counts().keys().tolist():
    a = dataFrameBig.loc[dataFrameBig['region']==i]
    plt.figure(figsize=(4,7))
    plt.title("вызовы в службы на территории"+' '+ i+' ' +"за 2020 и 2021 год")
    sns.barplot(y=a['type'].value_counts().keys(), x=a['type'].value_counts())
    plt.xlabel("число вызовов")

# %% [markdown]
# # Построение тепловой карты направлений (категорий)
# # происшествий (Типы направлений чрезвычайных ситуаций: ЧС на транспорте,
# #                ЧС в сфере ЖКХ, ЧС в сфере ТЭК и Промышленность, ЧС в сфере здравоохранения,
# #                ЧС, связанные с противоправными действиями);

# %%
dataFrameBig

# %%
dataFrameBig.index = range(0,338)

# %%
a = dataFrameBig['type'].value_counts().keys().tolist()
array = np.empty([len(dataFrameBig), len(dataFrameBig['type'].value_counts().keys().tolist())])
for  i in range(len(dataFrameBig['type'].value_counts().keys().tolist())):
    for j in range(len(dataFrameBig)):
        if dataFrameBig['type'].value_counts().keys().tolist()[i] == dataFrameBig['type'][j]:
            array[j][i] = 1 
        else:
            array[j][i] = 0

# %%
emergdf =  pd.DataFrame(array, columns=dataFrameBig['type'].value_counts().keys().tolist())

# %%
emergdf.index = dataFrameBig['region']

# %%
emergdf

# %%
df1 = emergdf.groupby(["region"]).sum()

# %%
df1.columns

# %%
df1['прочее'] = df1[['Детские шалости','Получение справок','Автоматические ложные вызовы','Неправильное понимание экстренной ситуации', 'Ложные вызовы вследствие сбоя в сети связи','Оскорбительные вызовы','Неправильный набор номера (ошибочный)','Другое','Соседний субъект','Тренировка']].sum(axis=1)
df1['ЧС связанные с противоправными действиями'] = df1[['Труп', 'Потерявшиеся граждане', 'Вскрытие дверей', 'Ножевое ранение', 'Угон транспортного средства', 'Правонарушение','Злонамеренные вызовы','Кража','Семейный конфликт']].sum(axis=1)
df1['ЧС в сфере здравоохранения'] = df1[['Оказание медицинской помощи', '2019-nCoV без симптомов', '2019-nCov: консультация', 'Психически неуравновешенные люди','Психологическая помощь','Covid  Товары и услуги','Covid  Симптомы' ]].sum(axis=1)
df1['Природные ЧС'] = df1[['Пожар ландшафтный', 'Водоотведение','Гололёд']].sum(axis=1)
df1['ЧС в сфере ЖКХ'] = df1[['Запах газа в жилом здании', 'Помощь населению','Электроснабжение','Газоснабжение','Водоснабжение']].sum(axis=1)
df1['ЧС на транспорте'] = df1[['ДТП с пострадавшими','Падение пассажира', 'ДТП','Авария на воздушном судне', 'Повреждение припаркованного транспортного средства','Застрявшие транспортные средства','Транспортные пробки',]].sum(axis=1)
df1 = df1.drop(['Получение справок', 'Детские шалости', 'Оказание медицинской помощи',
       'Автоматические ложные вызовы', 'ДТП', 'Запах газа в жилом здании',
       '2019-nCoV без симптомов', 'Пожар ландшафтный', 'Помощь населению',
       '2019-nCov: консультация', 'Неправильное понимание экстренной ситуации',
       'Психически неуравновешенные люди', 'Труп', 'Потерявшиеся граждане',
       'Вскрытие дверей', 'Ножевое ранение', 'Водоотведение',
       'Угон транспортного средства', 'ДТП с пострадавшими',
       'Падение пассажира', 'Правонарушение','Психологическая помощь', 'Соседний субъект',
       'Ложные вызовы вследствие сбоя в сети связи', 'Электроснабжение',
       'Тренировка', 'Оскорбительные вызовы',
       'Неправильный набор номера (ошибочный)', 'Злонамеренные вызовы',
       'Транспортные пробки', 'Кража', 'Гололёд',
       'Застрявшие транспортные средства', 'Семейный конфликт',
       'Covid  Товары и услуги',
       'Повреждение припаркованного транспортного средства', 'Газоснабжение',
       'Водоснабжение', 'Авария на воздушном судне', 'Covid  Симптомы',
       'Другое'], axis =1)

# %%
df1

# %%
# Set the width and height of the figure
plt.figure(figsize=(20,10))

# Add title
plt.title("Черезвычайные ситуации в районах за 2020 - 2021 годы")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=df1, annot=True)

# Add label for horizontal axis
plt.xlabel("Черезвычайная ситуация")
plt.savefig('your_figure.png')

# %% [markdown]
# # 3. Определение:
# # - зависимостей событий в привязке ко времени и координатам через слои нескольких типов направлений, выявление областей пересечения категорий происшествий

# %%
addictionDf = pd.concat([emergdf, dataFrameBig],axis = 1)
addictionDf.drop(['type'], axis = 1)

# %%
emergdf_No_Group = pd.concat([emergdf, dataFrameBig['region'], dataFrameBig['timeIsoStr']], axis =1)

# %%
emergdf_To_Group = pd.concat([emergdf, dataFrameBig['region'], dataFrameBig['timeIsoStr']], axis = 1)
emergdf_To_Group['прочее'] = emergdf_To_Group[['Детские шалости','Получение справок','Автоматические ложные вызовы','Неправильное понимание экстренной ситуации', 'Ложные вызовы вследствие сбоя в сети связи','Оскорбительные вызовы','Неправильный набор номера (ошибочный)','Другое','Соседний субъект','Тренировка']].sum(axis=1)
emergdf_To_Group['ЧС связанные с противоправными действиями'] = emergdf_To_Group[['Труп', 'Потерявшиеся граждане', 'Вскрытие дверей', 'Ножевое ранение', 'Угон транспортного средства', 'Правонарушение','Злонамеренные вызовы','Кража','Семейный конфликт']].sum(axis=1)
emergdf_To_Group['ЧС в сфере здравоохранения'] = emergdf_To_Group[['Оказание медицинской помощи', '2019-nCoV без симптомов', '2019-nCov: консультация', 'Психически неуравновешенные люди','Психологическая помощь','Covid  Товары и услуги','Covid  Симптомы' ]].sum(axis=1)
emergdf_To_Group['Природные ЧС'] = emergdf_To_Group[['Пожар ландшафтный', 'Водоотведение','Гололёд']].sum(axis=1)
emergdf_To_Group['ЧС в сфере ЖКХ'] = emergdf_To_Group[['Запах газа в жилом здании', 'Помощь населению','Электроснабжение','Газоснабжение','Водоснабжение']].sum(axis=1)
emergdf_To_Group['ЧС на транспорте'] = emergdf_To_Group[['ДТП с пострадавшими','Падение пассажира', 'ДТП','Авария на воздушном судне', 'Повреждение припаркованного транспортного средства','Застрявшие транспортные средства','Транспортные пробки',]].sum(axis=1)
emergdf_To_Group = emergdf_To_Group.drop(['Получение справок', 'Детские шалости', 'Оказание медицинской помощи',
       'Автоматические ложные вызовы', 'ДТП', 'Запах газа в жилом здании',
       '2019-nCoV без симптомов', 'Пожар ландшафтный', 'Помощь населению',
       '2019-nCov: консультация', 'Неправильное понимание экстренной ситуации',
       'Психически неуравновешенные люди', 'Труп', 'Потерявшиеся граждане',
       'Вскрытие дверей', 'Ножевое ранение', 'Водоотведение',
       'Угон транспортного средства', 'ДТП с пострадавшими',
       'Падение пассажира', 'Правонарушение','Психологическая помощь', 'Соседний субъект',
       'Ложные вызовы вследствие сбоя в сети связи', 'Электроснабжение',
       'Тренировка', 'Оскорбительные вызовы',
       'Неправильный набор номера (ошибочный)', 'Злонамеренные вызовы',
       'Транспортные пробки', 'Кража', 'Гололёд',
       'Застрявшие транспортные средства', 'Семейный конфликт',
       'Covid  Товары и услуги',
       'Повреждение припаркованного транспортного средства', 'Газоснабжение',
       'Водоснабжение', 'Авария на воздушном судне', 'Covid  Симптомы',
       'Другое'], axis =1)

# %% [markdown]
# **Начнем находить зависимости событий в привязке ко времени и координатам**

# %% [markdown]
# Рассмотрим сперва ЧС на транспорте:
# * ДТП
# * ДТП с пострадавшими
# * Падение пассажира
# * Авария на воздушном судне
# * Повреждение припаркованного транспортного средства
# * Застрявшие транспортные средства
# * Транспортные пробки
#
# Всего по данным за два года в области произошло 24 происшествия на транспорте и 15 из них в Ворошиловском районе, посмотрим как связанны происшествия к привязке ко времени и месту:

# %%
df = emergdf_No_Group.loc[(emergdf_No_Group['region']=='Волгоград Ворошиловский')  & ((emergdf_No_Group['ДТП']>=1) | (emergdf_No_Group['ДТП с пострадавшими']>=1) | (emergdf_No_Group['Падение пассажира']>=1) | (emergdf_No_Group['Авария на воздушном судне']>=1) | (emergdf_No_Group['Повреждение припаркованного транспортного средства']>=1) | (emergdf_No_Group['Застрявшие транспортные средства']>=1) | (emergdf_No_Group['Транспортные пробки']>=1))][['ДТП','ДТП с пострадавшими','Падение пассажира','Авария на воздушном судне','Повреждение припаркованного транспортного средства','Застрявшие транспортные средства','Транспортные пробки','timeIsoStr']]
df.index = df['timeIsoStr']
df=df.drop(['timeIsoStr'],axis =1)

# %%
plt.figure(figsize=(15,10))
plt.title("ЧС на транспорте")
sns.heatmap(df)
#plt.xlabel()

# %% [markdown]
# ДТП происходят круглый год, кроме сентября и декабря)
# ДТП с пострадавшими появились в 21 году, причем последнии из них произошли в конце года,

# %% [markdown]
# Рассмотрим ЧС в сфере ЖКХ
# * 'Запах газа в жилом здании', 'Помощь населению','Электроснабжение','Газоснабжение','Водоснабжение'
# * Помощь населению
# * Электроснабжение
# * Газоснабжение
# * Водоснабжение
# *
# *

# %%
df = emergdf_No_Group.loc[(emergdf_No_Group['region']=='Волгоград Ворошиловский')  & ((emergdf_No_Group['Запах газа в жилом здании']>=1) | (emergdf_No_Group['Помощь населению']>=1) | (emergdf_No_Group['Электроснабжение']>=1) | (emergdf_No_Group['Газоснабжение']>=1) | (emergdf_No_Group['Водоснабжение']>=1) )][['Запах газа в жилом здании', 'Помощь населению','Электроснабжение','Газоснабжение','Водоснабжение','timeIsoStr']]
df.index = df['timeIsoStr']
df=df.drop(['timeIsoStr'],axis =1)
plt.figure(figsize=(15,10))
plt.title("ЧС в сфере ЖКХ")
sns.heatmap(df)
#plt.xlabel()

# %% [markdown]
# Основными проблемами в 2020 году были обращения по поводу запаха газа, причем все звонки были в один день и примерно в одно и тоже время, в 2021 году проблем с утечкой газа не было видно, основными темами обращений были по поводу электроснабжения, газоснабжения и водоснабжения, все эти проблемы просматривались весной 2021 года

# %% [markdown]
# **Рассмотрим ЧС в сфере здравоохранения**
# * Оказание медицинской помощи
# * 2019-nCoV без симптомов
# * 2019-nCov: консультация
# * Психически неуравновешенные люди
# * Психологическая помощь
# * Covid  Товары и услуги
# * Covid  Симптомы

# %%
df = emergdf_No_Group.loc[(emergdf_No_Group['region']=='Волгоград Ворошиловский')  & ((emergdf_No_Group['Оказание медицинской помощи']>=1) | (emergdf_No_Group['2019-nCoV без симптомов']>=1) | (emergdf_No_Group['2019-nCov: консультация']>=1) | (emergdf_No_Group['Психически неуравновешенные люди']>=1) | (emergdf_No_Group['Психологическая помощь']>=1)  )][['Оказание медицинской помощи', '2019-nCoV без симптомов', '2019-nCov: консультация', 'Психически неуравновешенные люди','Психологическая помощь','timeIsoStr']]
df.index = df['timeIsoStr']
df=df.drop(['timeIsoStr'],axis =1)
plt.figure(figsize=(15,10))
plt.title("ЧС в сфере здравоохранения")
sns.heatmap(df)
#plt.xlabel()

# %% [markdown]
# Можно заметить, что медицинская помощь оказывается в течении всего года, обращения с ковидом были в 2020 году, а звонки с психологическими заболеваниями оказывалась в основном в 2021 году.

# %% [markdown]
# **Рассмотрим природные ЧС:**
#  * Пожар ландшафтный
#  * Водоотведение
#  * Гололёд

# %%
df = emergdf_No_Group.loc[(emergdf_No_Group['region']=='Волгоград Ворошиловский')  & ((emergdf_No_Group['Пожар ландшафтный']>=1) | (emergdf_No_Group['Водоотведение']>=1) | (emergdf_No_Group['Гололёд']>=1) )][['Пожар ландшафтный','Водоотведение','Гололёд','timeIsoStr']]
df.index = df['timeIsoStr']
df=df.drop(['timeIsoStr'],axis =1)
plt.figure(figsize=(15,10))
plt.title("природные ЧС")
sns.heatmap(df)
#plt.xlabel()

# %% [markdown]
# В Ворошиловском районе основными природными происшествиями были пожары ландшафтно територии

# %% [markdown]
# **ЧС связанные с противоправными действиями**
#    * Труп
#    * Потерявшиеся граждане
#    * Вскрытие дверей
#    * Ножевое ранение
#    * Угон транспортного средства
#    * Правонарушение
#    * Злонамеренные вызовы
#    * Кража
#    * Семейный конфликт

# %%
df = emergdf_No_Group.loc[(emergdf_No_Group['region']=='Волгоград Ворошиловский')  & ((emergdf_No_Group['Труп']>=1) | (emergdf_No_Group['Потерявшиеся граждане']>=1) | (emergdf_No_Group['Вскрытие дверей']>=1) | (emergdf_No_Group['Ножевое ранение']>=1) | (emergdf_No_Group['Угон транспортного средства']>=1) | (emergdf_No_Group['Правонарушение']>=1) | (emergdf_No_Group['Злонамеренные вызовы']>=1) | (emergdf_No_Group['Кража']>=1) | (emergdf_No_Group['Семейный конфликт']>=1) )][['Труп', 'Потерявшиеся граждане', 'Вскрытие дверей', 'Ножевое ранение', 'Угон транспортного средства', 'Правонарушение','Злонамеренные вызовы','Кража','Семейный конфликт','timeIsoStr']]
df.index = df['timeIsoStr']
df=df.drop(['timeIsoStr'],axis =1)
plt.figure(figsize=(15,10))
plt.title("ЧС связанные с противоправными действиями")
sns.heatmap(df)
#plt.xlabel()

# %% [markdown]
# В основном среди противоправных действий встречаются правонарушения различной направлености, 2020 год был более тяжёлым, за этот год произошли два убийства, вскрытия дверей, ножевое ранение, угон транспортного средства.

# %% [markdown]
# ** 4. Составление прогноза вероятности возникновения событий (не менее 5 событий по каждому направлению):
# - гипотезы возникновения событий на основе анализа предоставленных данных
# - расчет вероятности возникновения происшествия, расчет ущерба, оценка риска
# - управленческие выводы по результатам анализа данных, с описанием логики либо алгоритма либо механизма принятия решения

# %% [markdown]
#  *вероят = число_благ_соб/число_всех_соб*

# %%
df = dataFrameBig['type'].value_counts()/dataFrameBig['type'].value_counts().sum()

# %%
df

# %%
df = pd.DataFrame(df)

# %%
df.rename(columns = {'type': 'вероятность события'}, inplace = True)

# %%
df
